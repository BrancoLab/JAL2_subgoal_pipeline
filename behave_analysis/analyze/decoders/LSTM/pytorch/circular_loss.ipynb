# %% [markdown]
# # Imports

# %%
import torch
import torch.distributions as dist

# %%
true_angle = 0 * torch.pi
pred_angle = - torch.pi

loss = - dist.VonMises(torch.Tensor([pred_angle]), torch.tensor([1.0])).log_prob(torch.Tensor([true_angle]))
loss
