# %% [markdown]
# Our ability to decode spatial efficiency might be a function of head direction encoding in the retrosplenial cortex. If this is true, any difference in behavioural sampling of head direction might permit a decoder to have above chance in accuracy. Thus checking that the highest coefficients do not have high rayleighs for head direction can support our claim that they are not head direction cells but are actually subgoal helper cells.
#
# From robin about doing it properly - Usually using a measure called KL divergence (Kullback-Liebler). Obvs read the Wikipedia entry on it but basically it's a measure of how much 2 distributions differ. In the case of hd cells you feed in two distributions, a uniform circular one (the expected dist under the null hypothesis) and your observed dist i.e. the polar plot from your cell. If I remember correctly, both distributions are normed to a max of 1. Ideally you'd generate a distribution of the KL score from a load of shuffled data to get your 95th or 99th prctile. In my experience anything with a score over about 0.15 is a hd cell
#
# Can I use rayleigh vector? With some cut off
# New
#
# rhayman
#   5:27 PM
# Yeah could do. Again it's a case of figuring out what a statistically valid cut off is. Time to get a shuffling :man_dancing: (edited)
#
# Laurence Freeman
#   5:29 PM
# Ok thanks mate
#
# rhayman
#   5:38 PM
# Code for KL div is here, the two functions only need numpy and you should be able to feed in just the binned directional 1D ratemap into the first function to get the KL score (famous last words)...
# https://github.com/rhayman/ephysiopy/blob/master/ephysiopy%2Fcommon%2Ffieldcalcs.py#L622-L725

# %%
# Approach 1: Use an industry defined definition of head direction cells
# I could have a percentage of cells. I.e what are the percentage of cells out of the top coefficients that are similar and have high rayleigh score

# %% [markdown]
# # Logic for classifying head direction cells

# %%
from loguru import logger

from behave_analysis.utils.rayleigh.load_rayleigh import extract_rayleigh_path, load_rayleigh_data
from behave_analysis.utils.rayleigh.manipulate_rayleigh_df import extract_compartment_values
from behave_analysis.analyze.classification.head_direction import angle_similarity, rayleigh_threshold, check_both_compartments_significant
from behave_analysis.process.session import get_experiment

# %%
# User defined constants
RAYLEIGH_THRESHOLD = 0.5
SIMILAR_ANGLE_THRESHOLD = 0.8

# %%
from behave_analysis.database.Experiments.JAL003_ex import JAL3_25aug, JAL3_1sept, JAL3_4sept, JAL3_7sept
from behave_analysis.database.Experiments.JAL004_ex import JAL4_3rdSept, JAL4_19thSept, JAL4_28aug, JAL4_11thSept
from behave_analysis.database.Experiments.JAL005_ex import JAL005_8thSept, JAL005_21stSept
from behave_analysis.database.Experiments.JAL006_ex import JAL6_28mar, JAL6_flip4_21mar, JAL6_flip5_25mar, JAL6_flip3_18mar, JAL6_flip7_1apr
from behave_analysis.database.Experiments.JAL007_ex import (
    JAL7_sesh8_9apr,
    JAL7_sesh9_16apr,
    JAL7_flip5_22mar,
    JAL7_flip2_12mar,
    JAL7_23apr,
    JAL7_30apr,
)
from behave_analysis.database.Experiments.JAL008_ex import (
    JAL8_flip1_25apr,
    JAL8_flip2_29apr,
    JAL8_tiny_3may,
    JAL8_flip4_10may,
    JAL8_14may,
    JAL8_21may,
    JAL8_flip3_7may,
)

# The values must be in order of data for the code to work
mice_groups = {
    "JAL6": ["JAL6_flip3_18mar", "JAL6_flip4_21mar", "JAL6_flip5_25mar", "JAL6_28mar"],
    "JAL3": ["JAL3_25aug", "JAL3_1sept", "JAL3_4sept", "JAL3_7sept"],
    "JAL7": ["JAL7_flip2_12mar", "JAL7_flip5_22mar", "JAL7_sesh8_9apr", "JAL7_sesh9_16apr", "JAL7_23apr"],
    "JAL8": ["JAL8_flip1_25apr", "JAL8_flip2_29apr", "JAL8_flip4_10may", "JAL8_flip3_7may", "JAL8_14may"],
    "JAL4": ["JAL4_28aug", "JAL4_3rdSept", "JAL4_11thSept", "JAL4_19thSept"],
    "JAL5": ["JAL5_8thSept", "JAL5_21stSept"],
}

# The experiment objects index must match the session name index for the code to work
experiments_objects = [
    JAL6_flip3_18mar,
    JAL6_flip4_21mar,
    JAL6_flip5_25mar,
    JAL6_28mar,
    JAL3_25aug,
    JAL3_1sept,
    JAL3_4sept,
    JAL3_7sept,
    JAL005_8thSept,
    JAL005_21stSept,
    JAL7_sesh8_9apr,
    JAL7_sesh9_16apr,
    JAL7_flip5_22mar,
    JAL7_flip2_12mar,
    JAL7_23apr,
    JAL8_flip1_25apr,
    JAL8_flip2_29apr,
    JAL8_flip4_10may,
    JAL8_14may,
    JAL8_flip3_7may,
    JAL4_3rdSept,
    JAL4_19thSept,
    JAL4_28aug,
    JAL4_11thSept,
]

# The session name indexes must match the experiment object indexes
session_names = [
    "JAL6_flip3_18mar",
    "JAL6_flip4_21mar",
    "JAL6_flip5_25mar",
    "JAL6_28mar",
    "JAL3_25aug",
    "JAL3_1sept",
    "JAL3_4sept",
    "JAL3_7sept",
    "JAL5_8thSept",
    "JAL5_21stSept",
    "JAL7_sesh8_9apr",
    "JAL7_sesh9_16apr",
    "JAL7_flip5_22mar",
    "JAL7_flip2_12mar",
    "JAL7_23apr",
    "JAL8_flip1_25apr",
    "JAL8_flip2_29apr",
    "JAL8_flip4_10may",
    "JAL8_14may",
    "JAL8_flip3_7may",
    "JAL4_3rdSept",
    "JAL4_19thSept",
    "JAL4_28aug",
    "JAL4_11thSept",
]

# %%
def classify_hdir(session: object, cluster_type: str = "good") -> list:
    """Label cells as head direction based on a set of criteria

    Returns:
    -- cell ids (list) that are head direction cells"""
    path = extract_rayleigh_path(session, cluster_type, condition="shelter_only", file_name="hdir_Rayleigh.arrow")
    data = load_rayleigh_data(path)
    angles = extract_compartment_values(data, "Rayleigh_theta")
    magnitude = extract_compartment_values(data, "Rayleigh")
    sig = extract_compartment_values(data, "Rayleigh_sig")
    head_direction_cells = []
    for row, cell_id in enumerate(data["clusterID"]):
        simlar_angles = angle_similarity(angles[row][0], angles[row][1])
        above_threshold = rayleigh_threshold(magnitude[row][0], magnitude[row][1])
        sig_bool = check_both_compartments_significant(sig[row])
        if simlar_angles > SIMILAR_ANGLE_THRESHOLD and above_threshold and sig_bool:
            head_direction_cells.append(cell_id)
    logger.info(f"Found {len(head_direction_cells)} head direction cells")
    logger.info(f"Head direction cells: {head_direction_cells}")
    return head_direction_cells

# %%
from collections import defaultdict
head_direction_cells = defaultdict(list)
for experiment, session_name in zip(experiments_objects, session_names):
    logger.info(f"Loading data for session: {session_name}")
    loaded_session = get_experiment(experiment)
    cells = classify_hdir(loaded_session)
    head_direction_cells[session_name] = cells
# Out:
# 2025-01-15 13:59:00.044 | INFO     | __main__:<module>:4 - Loading data for session: JAL6_flip3_18mar
# 2025-01-15 13:59:00.315 | INFO     | __main__:classify_hdir:18 - Found 7 head direction cells
# 2025-01-15 13:59:00.316 | INFO     | __main__:classify_hdir:19 - Head direction cells: [140.0, 207.0, 212.0, 266.0, 435.0, 474.0, 546.0]
# 2025-01-15 13:59:00.317 | INFO     | __main__:<module>:4 - Loading data for session: JAL6_flip4_21mar
# 2025-01-15 13:59:00.424 | INFO     | __main__:classify_hdir:18 - Found 9 head direction cells
# 2025-01-15 13:59:00.425 | INFO     | __main__:classify_hdir:19 - Head direction cells: [150.0, 152.0, 236.0, 466.0, 467.0, 470.0, 578.0, 579.0, 610.0]
# 2025-01-15 13:59:00.426 | INFO     | __main__:<module>:4 - Loading data for session: JAL6_flip5_25mar
# 2025-01-15 13:59:00.607 | INFO     | __main__:classify_hdir:18 - Found 3 head direction cells
# 2025-01-15 13:59:00.607 | INFO     | __main__:classify_hdir:19 - Head direction cells: [347.0, 348.0, 371.0]
# 2025-01-15 13:59:00.608 | INFO     | __main__:<module>:4 - Loading data for session: JAL6_28mar
# 2025-01-15 13:59:00.718 | INFO     | __main__:classify_hdir:18 - Found 3 head direction cells
# 2025-01-15 13:59:00.719 | INFO     | __main__:classify_hdir:19 - Head direction cells: [147.0, 384.0, 467.0]
# 2025-01-15 13:59:00.720 | INFO     | __main__:<module>:4 - Loading data for session: JAL3_25aug
# 2025-01-15 13:59:00.785 | INFO     | __main__:classify_hdir:18 - Found 0 head direction cells
# 2025-01-15 13:59:00.785 | INFO     | __main__:classify_hdir:19 - Head direction cells: []
# 2025-01-15 13:59:00.786 | INFO     | __main__:<module>:4 - Loading data for session: JAL3_1sept
# 2025-01-15 13:59:00.854 | INFO     | __main__:classify_hdir:18 - Found 0 head direction cells
# 2025-01-15 13:59:00.855 | INFO     | __main__:classify_hdir:19 - Head direction cells: []
# 2025-01-15 13:59:00.856 | INFO     | __main__:<module>:4 - Loading data for session: JAL3_4sept
# 2025-01-15 13:59:00.920 | INFO     | __main__:classify_hdir:18 - Found 0 head direction cells
# 2025-01-15 13:59:00.920 | INFO     | __main__:classify_hdir:19 - Head direction cells: []
# 2025-01-15 13:59:00.921 | INFO     | __main__:<module>:4 - Loading data for session: JAL3_7sept
# 2025-01-15 13:59:00.996 | INFO     | __main__:classify_hdir:18 - Found 0 head direction cells
# 2025-01-15 13:59:00.996 | INFO     | __main__:classify_hdir:19 - Head direction cells: []
# 2025-01-15 13:59:00.997 | INFO     | __main__:<module>:4 - Loading data for session: JAL5_8thSept
# 2025-01-15 13:59:01.064 | INFO     | __main__:classify_hdir:18 - Found 5 head direction cells
# 2025-01-15 13:59:01.065 | INFO     | __main__:classify_hdir:19 - Head direction cells: [309.0, 310.0, 498.0, 618.0, 911.0]
# 2025-01-15 13:59:01.066 | INFO     | __main__:<module>:4 - Loading data for session: JAL5_21stSept
# 2025-01-15 13:59:01.162 | INFO     | __main__:classify_hdir:18 - Found 3 head direction cells
# 2025-01-15 13:59:01.162 | INFO     | __main__:classify_hdir:19 - Head direction cells: [107.0, 542.0, 757.0]
# 2025-01-15 13:59:01.163 | INFO     | __main__:<module>:4 - Loading data for session: JAL7_sesh8_9apr
# 2025-01-15 13:59:01.289 | INFO     | __main__:classify_hdir:18 - Found 2 head direction cells
# 2025-01-15 13:59:01.290 | INFO     | __main__:classify_hdir:19 - Head direction cells: [394.0, 443.0]
# 2025-01-15 13:59:01.291 | INFO     | __main__:<module>:4 - Loading data for session: JAL7_sesh9_16apr
# 2025-01-15 13:59:01.457 | INFO     | __main__:classify_hdir:18 - Found 4 head direction cells
# 2025-01-15 13:59:01.458 | INFO     | __main__:classify_hdir:19 - Head direction cells: [163.0, 164.0, 360.0, 370.0]
# 2025-01-15 13:59:01.459 | INFO     | __main__:<module>:4 - Loading data for session: JAL7_flip5_22mar
# 2025-01-15 13:59:01.532 | INFO     | __main__:classify_hdir:18 - Found 7 head direction cells
# 2025-01-15 13:59:01.532 | INFO     | __main__:classify_hdir:19 - Head direction cells: [173.0, 181.0, 182.0, 483.0, 489.0, 493.0, 599.0]
# 2025-01-15 13:59:01.533 | INFO     | __main__:<module>:4 - Loading data for session: JAL7_flip2_12mar
# 2025-01-15 13:59:01.610 | INFO     | __main__:classify_hdir:18 - Found 1 head direction cells
# 2025-01-15 13:59:01.611 | INFO     | __main__:classify_hdir:19 - Head direction cells: [279.0]
# 2025-01-15 13:59:01.612 | INFO     | __main__:<module>:4 - Loading data for session: JAL7_23apr
# 2025-01-15 13:59:01.691 | INFO     | __main__:classify_hdir:18 - Found 1 head direction cells
# 2025-01-15 13:59:01.691 | INFO     | __main__:classify_hdir:19 - Head direction cells: [261.0]
# 2025-01-15 13:59:01.692 | INFO     | __main__:<module>:4 - Loading data for session: JAL8_flip1_25apr
# 2025-01-15 13:59:02.031 | INFO     | __main__:classify_hdir:18 - Found 2 head direction cells
# 2025-01-15 13:59:02.032 | INFO     | __main__:classify_hdir:19 - Head direction cells: [423.0, 451.0]
# 2025-01-15 13:59:02.033 | INFO     | __main__:<module>:4 - Loading data for session: JAL8_flip2_29apr
# 2025-01-15 13:59:02.200 | INFO     | __main__:classify_hdir:18 - Found 1 head direction cells
# 2025-01-15 13:59:02.201 | INFO     | __main__:classify_hdir:19 - Head direction cells: [649.0]
# 2025-01-15 13:59:02.201 | INFO     | __main__:<module>:4 - Loading data for session: JAL8_flip4_10may
# 2025-01-15 13:59:02.253 | INFO     | __main__:classify_hdir:18 - Found 0 head direction cells
# 2025-01-15 13:59:02.254 | INFO     | __main__:classify_hdir:19 - Head direction cells: []
# 2025-01-15 13:59:02.254 | INFO     | __main__:<module>:4 - Loading data for session: JAL8_14may
# 2025-01-15 13:59:02.379 | INFO     | __main__:classify_hdir:18 - Found 0 head direction cells
# 2025-01-15 13:59:02.380 | INFO     | __main__:classify_hdir:19 - Head direction cells: []
# 2025-01-15 13:59:02.381 | INFO     | __main__:<module>:4 - Loading data for session: JAL8_flip3_7may
# 2025-01-15 13:59:02.436 | INFO     | __main__:classify_hdir:18 - Found 0 head direction cells
# 2025-01-15 13:59:02.436 | INFO     | __main__:classify_hdir:19 - Head direction cells: []
# 2025-01-15 13:59:02.437 | INFO     | __main__:<module>:4 - Loading data for session: JAL4_3rdSept
# 2025-01-15 13:59:02.510 | INFO     | __main__:classify_hdir:18 - Found 32 head direction cells
# 2025-01-15 13:59:02.510 | INFO     | __main__:classify_hdir:19 - Head direction cells: [6.0, 11.0, 22.0, 23.0, 35.0, 45.0, 49.0, 52.0, 55.0, 58.0, 62.0, 66.0, 72.0, 79.0, 83.0, 88.0, 94.0, 101.0, 386.0, 518.0, 519.0, 524.0, 526.0, 535.0, 536.0, 629.0, 631.0, 679.0, 681.0, 704.0, 880.0, 928.0]
# 2025-01-15 13:59:02.512 | INFO     | __main__:<module>:4 - Loading data for session: JAL4_19thSept
# 2025-01-15 13:59:02.687 | INFO     | __main__:classify_hdir:18 - Found 26 head direction cells
# 2025-01-15 13:59:02.687 | INFO     | __main__:classify_hdir:19 - Head direction cells: [9.0, 11.0, 12.0, 13.0, 17.0, 18.0, 20.0, 31.0, 35.0, 41.0, 53.0, 274.0, 376.0, 381.0, 385.0, 386.0, 388.0, 394.0, 429.0, 438.0, 450.0, 454.0, 490.0, 498.0, 557.0, 615.0]
# 2025-01-15 13:59:02.688 | INFO     | __main__:<module>:4 - Loading data for session: JAL4_28aug
# 2025-01-15 13:59:02.793 | INFO     | __main__:classify_hdir:18 - Found 25 head direction cells
# 2025-01-15 13:59:02.793 | INFO     | __main__:classify_hdir:19 - Head direction cells: [8.0, 12.0, 18.0, 20.0, 22.0, 24.0, 31.0, 32.0, 38.0, 42.0, 47.0, 236.0, 258.0, 358.0, 362.0, 363.0, 369.0, 371.0, 372.0, 374.0, 392.0, 470.0, 528.0, 567.0, 589.0]
# 2025-01-15 13:59:02.795 | INFO     | __main__:<module>:4 - Loading data for session: JAL4_11thSept
# 2025-01-15 13:59:02.866 | INFO     | __main__:classify_hdir:18 - Found 33 head direction cells
# 2025-01-15 13:59:02.866 | INFO     | __main__:classify_hdir:19 - Head direction cells: [20.0, 21.0, 34.0, 35.0, 36.0, 38.0, 45.0, 58.0, 61.0, 66.0, 68.0, 71.0, 73.0, 74.0, 80.0, 84.0, 87.0, 91.0, 96.0, 99.0, 112.0, 678.0, 683.0, 689.0, 706.0, 902.0, 903.0, 910.0, 994.0, 1004.0, 1006.0, 1105.0, 1175.0]

# %%
head_direction_cells
from pathlib import Path
dir = Path("Z:\Jasmine_Laurence\single_trial_overview\decoding_spatial_efficiency")

# Save the head direction cells
import pickle
with open(dir / "head_direction_cells.pkl", "wb") as f:
    pickle.dump(head_direction_cells, f)
